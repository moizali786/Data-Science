# %%
print("Twinkle Twinkle Little Star,\n\tHow I Wonder What You Are!\n\t\tUp Above The World So High,\n\t\tLike A Diamond In The Sky.\nTwinkle Twinkle Little Star,\n\tHow I Wonder What You Are");
# Out:
# Twinkle Twinkle Little Star,
# 	How I Wonder What You Are!
# 		Up Above The World So High,
# 		Like A Diamond In The Sky.
# Twinkle Twinkle Little Star,
# 	How I Wonder What You Are

# %%
import sys;
print("Python Version is :",sys.version);
# Out:
# Python Version is : 3.6.13 | packaged by conda-forge | (default, Sep 23 2021, 07:56:31)
# [GCC 9.4.0]

# %%
from datetime import datetime;
print("Today's Date and Time is :", datetime.now());
# Out:
# Today's Date and Time is : 2021-12-29 20:44:50.459417

# %%
import math;
userinpt = input("Enter Radius Of a Circle : ");
cnvrtdinpt = int(userinpt);
area = math.pi * (cnvrtdinpt**2);
print("Area Of Ciclre Is :",area);
# Out:
# Enter Radius Of a Circle : 8
# Area Of Ciclre Is : 201.06192982974676

# %%
firstname = input("Enter Your First Name : ");
lastname  = input("Enter Your Last Name : ");
print(lastname,firstname);
# Out:
# Enter Your First Name : Moiz
# Enter Your Last Name : Ali
# Ali Moiz

# %%
firstnum   = input("Enter First Number : ");
secondnum  = input("Enter Second Number : ");
result = int(firstnum) + int(secondnum);
print("Sum of",firstnum,"+",secondnum,"is :",result);
# Out:
# Enter First Number : 6
# Enter Second Number : 12
# Sum of 6 + 12 is : 18
